# %%
# pip install pandas
# Out:
# Requirement already satisfied: pandas in x:\anna\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in x:\anna\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in x:\anna\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in x:\anna\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in x:\anna\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in x:\anna\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
#series=1D labelled array
#DataFrame=2D labelled array(eg:table)

# %%
info={
    "Name":["Yash","Monty","Gaurav","Digvijay"],
    "CGPA":[9.5,8,9,10]
}
df=pd.DataFrame(info)
print(df)
# Out:
#        Name  CGPA
# 0      Yash   9.5
# 1     Monty   8.0
# 2    Gaurav   9.0
# 3  Digvijay  10.0

# %%
df
# Out:
#        Name  CGPA
# 0      Yash   9.5
# 1     Monty   8.0
# 2    Gaurav   9.0
# 3  Digvijay  10.0

# %%
#series
s=pd.Series([1,2,3,4,5])
print(type(s),s)

#index
print(s[0])
print(s[3])
# Out:
# <class 'pandas.core.series.Series'> 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 1
# 4

# %%
s=pd.Series([23,24,25,26],index=["Adam","Eve","Bob","Charlie"])
print(s)
print(s["Bob"])
# print(s[0])
print(s.index)
# Out:
# Adam       23
# Eve        24
# Bob        25
# Charlie    26
# dtype: int64
# 25
# Index(['Adam', 'Eve', 'Bob', 'Charlie'], dtype='object')
