# %%
import numpy as np
import time

# %%
a=[1,2,3,4,5]
print(type(a))
# Out:
# <class 'list'>

# %%
arr=np.array([1,2,3,4,5])
print(arr,type(arr))
# Out:
# [1 2 3 4 5] <class 'numpy.ndarray'>

# %%
#compare execution performance
size=1_000_000
py_list=list(range(size))
start=time.time()
sq_list=[x**2 for x in py_list]
end=time.time()
print(f"python list time ={end-start} seconds")
np_arr=np.array(py_list)
start=time.time()
sq_arr=np_arr**2 # vectorization
end=time.time()
print(f"nimpy array time ={end-start} seconds")
# Out:
# python list time =0.5000202655792236 seconds
# nimpy array time =0.03558802604675293 seconds

# %%
#memory comparison
import sys
print(f"python list size = {sys.getsizeof(py_list)*len(py_list)} bytes")
print(f"numpy array size ={np_arr.nbytes} bytes")
# Out:
# python list size = 8000056000000 bytes
# numpy array size =8000000 bytes
