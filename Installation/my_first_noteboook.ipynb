# %%
print("hello world")
# Out:
# hello world

# %%
a=10
b=12

# %%
print(a+b)
# Out:
# 22

# %%
print("HOIIE")
# Out:
# HOIIE

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# #hiee

# %% [markdown]
# #FIRST TUTORIAL
# ## This is installation demo

# %% [markdown]
# # First Tutorial
